# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r"C:\Users\admin\Downloads\world_population_excel_workbook.xlsx")
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara         El AaiÃºn    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
pd.set_option('display.float_format', lambda x:'%.2f' % x)
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara         El AaiÃºn    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
df.describe()
# Out:
#         Rank  2022 Population  2020 Population  2015 Population  \
# count 234.00           234.00           234.00           234.00
# mean  117.50      34074414.71      33501070.95      31729956.24
# std    67.69     136766424.80     135589876.92     130404992.75
# min     1.00           510.00           520.00           564.00
# 25%    59.25        419738.50        415284.50        404676.00
# 50%   117.50       5559944.50       5493074.50       5307400.00
# 75%   175.75      22476504.75      21447979.50      19730853.75
# max   234.00    1425887337.00    1424929781.00    1393715448.00
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count           234.00           234.00           234.00           234.00
# mean       29845235.03      26269468.82      22710220.79      18984616.97
# std       124218487.63     111698206.72      97832173.35      81785186.08
# min             596.00           651.00           700.00           733.00
# ...

# %%
df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                0
# 2020 Population                0
# 2015 Population                0
# 2010 Population                0
# 2000 Population                0
# 1990 Population                0
# 1980 Population                0
# 1970 Population                0
# Area (kmÂ²)                    0
# Density (per kmÂ²)             0
# Growth Rate                    0
# World Population Percentage    0
# dtype: int64

# %%
df.nunique()
# Out:
# Rank                           234
# CCA3                           234
# Country                        234
# Capital                        234
# Continent                        6
# 2022 Population                234
# 2020 Population                234
# 2015 Population                234
# 2010 Population                234
# 2000 Population                234
# 1990 Population                234
# 1980 Population                234
# 1970 Population                234
# Area (kmÂ²)                    233
# Density (per kmÂ²)             234
# Growth Rate                    180
# World Population Percentage     70
# dtype: int64

# %%
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara         El AaiÃºn    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
df.sort_values(by = "2022 Population", ascending = False).head(10)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 27      7  BRA         Brazil          Brasilia  South America
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 131    10  MEX         Mexico       Mexico City  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41        1425887337       1424929781       1393715448       1348191368
# 92        1417173173       1396387127       1322866505       1240613620
# ...

# %%
# corr used usually on numeric value
df.corr()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_18860\3639991315.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                              Rank  2022 Population  2020 Population  \
# Rank                         1.00            -0.36            -0.36
# 2022 Population             -0.36             1.00             1.00
# 2020 Population             -0.36             1.00             1.00
# 2015 Population             -0.35             1.00             1.00
# 2010 Population             -0.35             1.00             1.00
# 2000 Population             -0.34             0.99             1.00
# 1990 Population             -0.34             0.99             0.99
# 1980 Population             -0.34             0.98             0.98
# ...

# %%
sns.heatmap(df.corr(), annot = True)
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_18860\3614615914.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True)

# %%
sns.heatmap(df.corr(), annot = True)
plt.rcParams['figure.figsize'] = (12, 9)
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_18860\501285883.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True)

# %%
df.groupby("Continent").mean()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_18860\1051583130.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Continent").mean()
#                 Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Africa         92.16      25030367.23      23871435.26      21071972.67
# Asia           77.56      94427665.48      93261730.70      89165003.64
# Europe        124.50      14862950.76      14915843.92      14830712.16
# North America 160.93      15007403.40      14855914.82      14259596.25
# Oceania       188.52       1958198.00       1910148.96       1756664.48
# South America  97.57      31201186.29      30823574.50      29509599.71
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# ...

# %%
df[df['Continent'].str.contains("Oceania")]
# Out:
#      Rank CCA3                   Country       Capital Continent  \
# 3     213  ASM            American Samoa     Pago Pago   Oceania
# 11     55  AUS                 Australia      Canberra   Oceania
# 44    223  COK              Cook Islands        Avarua   Oceania
# 66    162  FJI                      Fiji          Suva   Oceania
# 70    183  PYF          French Polynesia       Papeete   Oceania
# 81    191  GUM                      Guam     HagÃ¥tÃ±a   Oceania
# 107   192  KIR                  Kiribati        Tarawa   Oceania
# 126   215  MHL          Marshall Islands        Majuro   Oceania
# 132   194  FSM                Micronesia       Palikir   Oceania
# 142   225  NRU                     Nauru         Yaren   Oceania
# 145   185  NCL             New Caledonia       NoumÃ©a   Oceania
# 146   123  NZL               New Zealand    Wellington   Oceania
# 150   232  NIU                      Niue         Alofi   Oceania
# ...

# %%
df.groupby('Continent').mean()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_18860\3700721160.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Continent').mean()
#                 Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Africa         92.16      25030367.23      23871435.26      21071972.67
# Asia           77.56      94427665.48      93261730.70      89165003.64
# Europe        124.50      14862950.76      14915843.92      14830712.16
# North America 160.93      15007403.40      14855914.82      14259596.25
# Oceania       188.52       1958198.00       1910148.96       1756664.48
# South America  97.57      31201186.29      30823574.50      29509599.71
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# ...

# %%
df.groupby('Continent').mean().sort_values(by = "2022 Population", ascending = False)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_18860\3693893611.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Continent').mean().sort_values(by = "2022 Population", ascending = False)
#                 Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Asia           77.56      94427665.48      93261730.70      89165003.64
# South America  97.57      31201186.29      30823574.50      29509599.71
# Africa         92.16      25030367.23      23871435.26      21071972.67
# North America 160.93      15007403.40      14855914.82      14259596.25
# Europe        124.50      14862950.76      14915843.92      14830712.16
# Oceania       188.52       1958198.00       1910148.96       1756664.48
#
# ...

# %%
df2 = df.groupby('Continent').mean(numeric_only=True).sort_values(by = "2022 Population", ascending = False)
df2
# Out:
#                 Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Asia           77.56      94427665.48      93261730.70      89165003.64
# South America  97.57      31201186.29      30823574.50      29509599.71
# Africa         92.16      25030367.23      23871435.26      21071972.67
# North America 160.93      15007403.40      14855914.82      14259596.25
# Europe        124.50      14862950.76      14915843.92      14830712.16
# Oceania       188.52       1958198.00       1910148.96       1756664.48
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Asia               84400826.54      74701792.08      64211271.54
# South America      28077017.86      24973877.29      21224743.93
# Africa             18512773.19      14367474.25      11195625.07
# North America      13568016.28      12151739.60      10531660.62
# Europe             14712278.68      14521868.46      14406415.94
# ...

# %%
df2.plot()
# Out:
# <Axes: xlabel='Continent'>

# %%
df3 = df2.transpose()
df3
# Out:
# Continent                          Asia  South America      Africa  \
# Rank                              77.56          97.57       92.16
# 2022 Population             94427665.48    31201186.29 25030367.23
# 2020 Population             93261730.70    30823574.50 23871435.26
# 2015 Population             89165003.64    29509599.71 21071972.67
# 2010 Population             84400826.54    28077017.86 18512773.19
# 2000 Population             74701792.08    24973877.29 14367474.25
# 1990 Population             64211271.54    21224743.93 11195625.07
# 1980 Population             52706684.56    17270643.29  8448006.61
# 1970 Population             42898125.80    13781939.71  6411304.35
# Area (kmÂ²)                   642762.82     1273813.00   531894.09
# Density (per kmÂ²)              1025.02          20.97      125.05
# Growth Rate                        1.01           1.01        1.02
# World Population Percentage        1.18           0.39        0.31
#
# ...

# %%
df3.plot()
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country', 'Capital', 'Continent', '2022 Population',
#        '2020 Population', '2015 Population', '2010 Population',
#        '2000 Population', '1990 Population', '1980 Population',
#        '1970 Population', 'Area (kmÂ²)', 'Density (per kmÂ²)', 'Growth Rate',
#        'World Population Percentage'],
#       dtype='object')

# %%
df.groupby('Continent')[['2022 Population',
       '2020 Population', '2015 Population', '2010 Population',
       '2000 Population', '1990 Population', '1980 Population',
       '1970 Population']].mean().sort_values(by = "2022 Population", ascending = False)
# Out:
#                2022 Population  2020 Population  2015 Population  \
# Continent
# Asia               94427665.48      93261730.70      89165003.64
# South America      31201186.29      30823574.50      29509599.71
# Africa             25030367.23      23871435.26      21071972.67
# North America      15007403.40      14855914.82      14259596.25
# Europe             14862950.76      14915843.92      14830712.16
# Oceania             1958198.00       1910148.96       1756664.48
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Asia               84400826.54      74701792.08      64211271.54
# South America      28077017.86      24973877.29      21224743.93
# Africa             18512773.19      14367474.25      11195625.07
# North America      13568016.28      12151739.60      10531660.62
# Europe             14712278.68      14521868.46      14406415.94
# Oceania             1613163.65       1357512.09       1162774.87
#
# ...

# %%
df.groupby('Continent')[df.columns[5:13]].mean().sort_values(by = "2022 Population", ascending = False)
# Out:
#                2022 Population  2020 Population  2015 Population  \
# Continent
# Asia               94427665.48      93261730.70      89165003.64
# South America      31201186.29      30823574.50      29509599.71
# Africa             25030367.23      23871435.26      21071972.67
# North America      15007403.40      14855914.82      14259596.25
# Europe             14862950.76      14915843.92      14830712.16
# Oceania             1958198.00       1910148.96       1756664.48
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Asia               84400826.54      74701792.08      64211271.54
# South America      28077017.86      24973877.29      21224743.93
# Africa             18512773.19      14367474.25      11195625.07
# North America      13568016.28      12151739.60      10531660.62
# Europe             14712278.68      14521868.46      14406415.94
# Oceania             1613163.65       1357512.09       1162774.87
#
# ...

# %%
df4 = df.groupby('Continent')[df.columns[5:13]].mean().sort_values(by = "2022 Population", ascending = False)

# %%
df5 = df4.transpose()
df5
# Out:
# Continent              Asia  South America      Africa  North America  \
# 2022 Population 94427665.48    31201186.29 25030367.23    15007403.40
# 2020 Population 93261730.70    30823574.50 23871435.26    14855914.82
# 2015 Population 89165003.64    29509599.71 21071972.67    14259596.25
# 2010 Population 84400826.54    28077017.86 18512773.19    13568016.28
# 2000 Population 74701792.08    24973877.29 14367474.25    12151739.60
# 1990 Population 64211271.54    21224743.93 11195625.07    10531660.62
# 1980 Population 52706684.56    17270643.29  8448006.61     9207334.03
# 1970 Population 42898125.80    13781939.71  6411304.35     7885865.15
#
# Continent            Europe    Oceania
# 2022 Population 14862950.76 1958198.00
# 2020 Population 14915843.92 1910148.96
# 2015 Population 14830712.16 1756664.48
# 2010 Population 14712278.68 1613163.65
# 2000 Population 14521868.46 1357512.09
# 1990 Population 14406415.94 1162774.87
# 1980 Population 13850543.18  996532.17
# ...

# %%
df5.plot()
# Out:
# <Axes: >

# %%
df5 = df.groupby('Continent')[df.columns[5:13]].mean()
df6 = df5.sort_values(by='2022 Population', ascending=False)
df6 = df6.iloc[:, ::-1]
df6
# Out:
#                1970 Population  1980 Population  1990 Population  \
# Continent
# Asia               42898125.80      52706684.56      64211271.54
# South America      13781939.71      17270643.29      21224743.93
# Africa              6411304.35       8448006.61      11195625.07
# North America       7885865.15       9207334.03      10531660.62
# Europe             13118479.82      13850543.18      14406415.94
# Oceania              846968.26        996532.17       1162774.87
#
#                2000 Population  2010 Population  2015 Population  \
# Continent
# Asia               74701792.08      84400826.54      89165003.64
# South America      24973877.29      28077017.86      29509599.71
# Africa             14367474.25      18512773.19      21071972.67
# North America      12151739.60      13568016.28      14259596.25
# Europe             14521868.46      14712278.68      14830712.16
# Oceania             1357512.09       1613163.65       1756664.48
#
# ...

# %%
# Or
df7 = df.groupby('Continent')[['1970 Population','1980 Population',
                        '1990 Population', '2000 Population',
                        '2010 Population','2015 Population',
                        '2020 Population','2022 Population']].mean().sort_values(by = "2022 Population", ascending = False)
# Out:
#                1970 Population  1980 Population  1990 Population  \
# Continent
# Asia               42898125.80      52706684.56      64211271.54
# South America      13781939.71      17270643.29      21224743.93
# Africa              6411304.35       8448006.61      11195625.07
# North America       7885865.15       9207334.03      10531660.62
# Europe             13118479.82      13850543.18      14406415.94
# Oceania              846968.26        996532.17       1162774.87
#
#                2000 Population  2010 Population  2015 Population  \
# Continent
# Asia               74701792.08      84400826.54      89165003.64
# South America      24973877.29      28077017.86      29509599.71
# Africa             14367474.25      18512773.19      21071972.67
# North America      12151739.60      13568016.28      14259596.25
# Europe             14521868.46      14712278.68      14830712.16
# Oceania             1357512.09       1613163.65       1756664.48
#
# ...

# %%
df = df6.transpose()
df
# Out:
# Continent              Asia  South America      Africa  North America  \
# 1970 Population 42898125.80    13781939.71  6411304.35     7885865.15
# 1980 Population 52706684.56    17270643.29  8448006.61     9207334.03
# 1990 Population 64211271.54    21224743.93 11195625.07    10531660.62
# 2000 Population 74701792.08    24973877.29 14367474.25    12151739.60
# 2010 Population 84400826.54    28077017.86 18512773.19    13568016.28
# 2015 Population 89165003.64    29509599.71 21071972.67    14259596.25
# 2020 Population 93261730.70    30823574.50 23871435.26    14855914.82
# 2022 Population 94427665.48    31201186.29 25030367.23    15007403.40
#
# Continent            Europe    Oceania
# 1970 Population 13118479.82  846968.26
# 1980 Population 13850543.18  996532.17
# 1990 Population 14406415.94 1162774.87
# 2000 Population 14521868.46 1357512.09
# 2010 Population 14712278.68 1613163.65
# 2015 Population 14830712.16 1756664.48
# 2020 Population 14915843.92 1910148.96
# ...

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.boxplot(figsize=(20,10))
# Out:
# <Axes: >

# %%
df
# Out:
# Continent              Asia  South America      Africa  North America  \
# 1970 Population 42898125.80    13781939.71  6411304.35     7885865.15
# 1980 Population 52706684.56    17270643.29  8448006.61     9207334.03
# 1990 Population 64211271.54    21224743.93 11195625.07    10531660.62
# 2000 Population 74701792.08    24973877.29 14367474.25    12151739.60
# 2010 Population 84400826.54    28077017.86 18512773.19    13568016.28
# 2015 Population 89165003.64    29509599.71 21071972.67    14259596.25
# 2020 Population 93261730.70    30823574.50 23871435.26    14855914.82
# 2022 Population 94427665.48    31201186.29 25030367.23    15007403.40
#
# Continent            Europe    Oceania
# 1970 Population 13118479.82  846968.26
# 1980 Population 13850543.18  996532.17
# 1990 Population 14406415.94 1162774.87
# 2000 Population 14521868.46 1357512.09
# 2010 Population 14712278.68 1613163.65
# 2015 Population 14830712.16 1756664.48
# 2020 Population 14915843.92 1910148.96
# ...

# %%
df.dtypes
# Out:
# Continent
# Asia             float64
# South America    float64
# Africa           float64
# North America    float64
# Europe           float64
# Oceania          float64
# dtype: object

# %%
df10 = df.select_dtypes(include='number')
df10
# Out:
# Continent              Asia  South America      Africa  North America  \
# 1970 Population 42898125.80    13781939.71  6411304.35     7885865.15
# 1980 Population 52706684.56    17270643.29  8448006.61     9207334.03
# 1990 Population 64211271.54    21224743.93 11195625.07    10531660.62
# 2000 Population 74701792.08    24973877.29 14367474.25    12151739.60
# 2010 Population 84400826.54    28077017.86 18512773.19    13568016.28
# 2015 Population 89165003.64    29509599.71 21071972.67    14259596.25
# 2020 Population 93261730.70    30823574.50 23871435.26    14855914.82
# 2022 Population 94427665.48    31201186.29 25030367.23    15007403.40
#
# Continent            Europe    Oceania
# 1970 Population 13118479.82  846968.26
# 1980 Population 13850543.18  996532.17
# 1990 Population 14406415.94 1162774.87
# 2000 Population 14521868.46 1357512.09
# 2010 Population 14712278.68 1613163.65
# 2015 Population 14830712.16 1756664.48
# 2020 Population 14915843.92 1910148.96
# ...

# %%
df10.dtypes
# Out:
# Continent
# Asia             float64
# South America    float64
# Africa           float64
# North America    float64
# Europe           float64
# Oceania          float64
# dtype: object

# %%
df.select_dtypes(include = 'float')
# Out:
# Continent              Asia  South America      Africa  North America  \
# 1970 Population 42898125.80    13781939.71  6411304.35     7885865.15
# 1980 Population 52706684.56    17270643.29  8448006.61     9207334.03
# 1990 Population 64211271.54    21224743.93 11195625.07    10531660.62
# 2000 Population 74701792.08    24973877.29 14367474.25    12151739.60
# 2010 Population 84400826.54    28077017.86 18512773.19    13568016.28
# 2015 Population 89165003.64    29509599.71 21071972.67    14259596.25
# 2020 Population 93261730.70    30823574.50 23871435.26    14855914.82
# 2022 Population 94427665.48    31201186.29 25030367.23    15007403.40
#
# Continent            Europe    Oceania
# 1970 Population 13118479.82  846968.26
# 1980 Population 13850543.18  996532.17
# 1990 Population 14406415.94 1162774.87
# 2000 Population 14521868.46 1357512.09
# 2010 Population 14712278.68 1613163.65
# 2015 Population 14830712.16 1756664.48
# 2020 Population 14915843.92 1910148.96
# ...

# %%
df.select_dtypes(include = 'object')
# Out:
# Empty DataFrame
# Columns: []
# Index: [1970 Population, 1980 Population, 1990 Population, 2000 Population, 2010 Population, 2015 Population, 2020 Population, 2022 Population]
